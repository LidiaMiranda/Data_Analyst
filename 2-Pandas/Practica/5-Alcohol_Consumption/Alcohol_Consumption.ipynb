# %% [markdown]
# # Ex - GroupBy

# %%
# !pip install mitosheet
# Out:
# ...
#      ---------------------------------------- 2.9/2.9 MB 18.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 149.9/149.9 kB ? eta 0:00:00
# ...
#      ------------------------------------- 199.1/199.1 kB 11.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 8.9/8.9 MB 35.4 MB/s eta 0:00:00
# ...
#      --------------------------------------- 15.3/15.3 MB 46.7 MB/s eta 0:00:00
# ...
#      ------------------------------------- 250.0/250.0 kB 15.0 MB/s eta 0:00:00
# ...
#      ------------------------------------- 529.8/529.8 kB 34.6 MB/s eta 0:00:00
# ...
#      --------------------------------------- 10.0/10.0 MB 45.8 MB/s eta 0:00:00
# ...
#      ------------------------------------- 347.4/347.4 kB 22.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 57.1/57.1 kB 2.9 MB/s eta 0:00:00
# ...
#      -------------------------------------- 133.1/133.1 kB 7.7 MB/s eta 0:00:00
# ...
#      ------------------------------------- 284.1/284.1 kB 17.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv).

# %%
drinks = pd.read_csv("drinks.csv")

# %% [markdown]
# ### Step 3. Assign it to a variable called drinks.

# %%
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %% [markdown]
# ### Step 4. Which continent drinks more beer on average?

# %%
beer=drinks.groupby ("continent").mean()[["beer_servings"]]
beer[beer["beer_servings"]== beer["beer_servings"].max()]
# Out:
#            beer_servings
# continent
# EU            193.777778

# %%
beer.sort_values("beer_servings", ascending=False).head(1)
# Out:
#            beer_servings
# continent
# EU            193.777778

# %%
# Out:
# continent                EU
# beer_servings    193.777778
# Name: 2, dtype: object

# %% [markdown]
# ### Step 5. For each continent print the statistics for wine consumption.

# %%
drinks.groupby("continent")["wine_servings"].describe()
# Out:
#            count        mean        std  min   25%    50%     75%    max
# continent
# AF          53.0   16.264151  38.846419  0.0   1.0    2.0   13.00  233.0
# AS          44.0    9.068182  21.667034  0.0   0.0    1.0    8.00  123.0
# EU          45.0  142.222222  97.421738  0.0  59.0  128.0  195.00  370.0
# OC          16.0   35.625000  64.555790  0.0   1.0    8.5   23.25  212.0
# SA          12.0   62.416667  88.620189  1.0   3.0   12.0   98.50  221.0

# %% [markdown]
# ### Step 6. Print the mean alcohol consumption per continent for every column

# %%
drinks.groupby("continent").mean()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
# EU            193.777778       132.555556     142.222222
# OC             89.687500        58.437500      35.625000
# SA            175.083333       114.750000      62.416667
#
#            total_litres_of_pure_alcohol
# continent
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# OC                             3.381250
# SA                             6.308333

# %% [markdown]
# ### Step 7. Print the median alcohol consumption per continent for every column

# %%
drinks.groupby("continent").median()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF                  32.0              3.0            2.0
# AS                  17.5             16.0            1.0
# EU                 219.0            122.0          128.0
# OC                  52.5             37.0            8.5
# SA                 162.5            108.5           12.0
#
#            total_litres_of_pure_alcohol
# continent
# AF                                 2.30
# AS                                 1.20
# EU                                10.00
# OC                                 1.75
# SA                                 6.85

# %%
# para hallar el máximo de litros
drinks.groupby("continent").median().loc[:,"total_litres_of_pure_alcohol"].max()
# Out:
# 10.0

# %%
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# EU                 219.0            122.0          128.0
#
#            total_litres_of_pure_alcohol
# continent
# EU                                 10.0

# %%
# Out:
# 34.8

# %%
# Out:
# 34.8

# %%
# Out:
# 39.0

# %% [markdown]
# ### Step 8. Print the mean, min and max values for spirit consumption per continent.

# %%
drinks.groupby("continent")["spirit_servings"].agg(["mean", "min", "max"])
# Out:
#                  mean  min  max
# continent
# AF          16.339623    0  152
# AS          60.840909    0  326
# EU         132.555556    0  373
# OC          58.437500    0  254
# SA         114.750000   25  302
